# %% [markdown]
# <a href="https://colab.research.google.com/github/alissonandradesilva506-a11y/Desafio-Sistema-de-Conta-Banc-ria-Digital/blob/main/Aula_12_08_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exemplos de importação
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configurando a conexão com o Google Drive

from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/UNIFSA/2025.2/Ciência de Dados/Atividades/Bases de dados/Aula 3/'
# Out:
# Mounted at /content/drive

# %%
# Leitura de diferentes formatos de aquivo

# CSV
# df_csv = pd.read_csv(path+"aula3_base_problema.csv")
df_csv = pd.read_csv(path+"aula3_base_problema.csv")


# Excel
# df_excel = pd.read_excel(path+"dados.xlsx")

# JSON
# df_json = pd.read_json(path+"dados.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_968/3639369037.py in <cell line: 0>()
#       3 # CSV
#       4 # df_csv = pd.read_csv(path+"aula3_base_exploracao.csv")
# ----> 5 df_csv = pd.read_csv(path+"aula3_base_problema.csv")
#       6
#       7
#
# ...

# %%
#INSPEÇÃO INICIAL

# Ver as primeiras linhas
print(df_csv.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_968/4134784158.py in <cell line: 0>()
#       2
#       3 # Ver as primeiras linhas
# ----> 4 print(df_csv.head())
#
# NameError: name 'df_csv' is not defined
